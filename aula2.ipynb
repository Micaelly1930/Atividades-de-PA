# %% [markdown]
# <a href="https://colab.research.google.com/github/Micaelly1930/Atividades-de-PA/blob/main/aula2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Aula de programação e algoritimos

# %%
lado1 = 2
lado2 = 3


# calculo da area

area = lado1 * lado2

# calculo da area de um quadrado

areaquadrado = lado1 *lado2

# %%
print (area)
# Out:
# 6

# %%
print (areaquadrado)
# Out:
# 6

# %%
nome = "Micaelly"
idade = 15
altura = 1,58

# %%
print (nome)
# Out:
# Micaelly

# %%
print (f"{nome}, idade: {idade}, altura {altura}")
# Out:
# Micaelly, idade: 15, altura (1, 58)
